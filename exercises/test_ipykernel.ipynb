# %%
# Test ipykernel
print("Hello World")
# Out:
# Hello World

# %%
from one_web_browsing_exercise import result

# %%
print(result)
# Out:
# messages=[TextMessage(id='41c697ca-9a20-4ed0-acdc-c0e136395442', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 12, 3, 13, 58, 0, 424335, tzinfo=datetime.timezone.utc), content='Find information about Kantega', type='TextMessage'), ToolCallRequestEvent(id='5addf04e-f1dd-458d-88a6-932ac41bff3e', source='assistant', models_usage=RequestUsage(prompt_tokens=62, completion_tokens=17), metadata={}, created_at=datetime.datetime(2025, 12, 3, 13, 58, 1, 385394, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_jRowbr3UoNEMYVymDSSnPNEu', arguments='{"query":"Kantega"}', name='web_search')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='5524628d-956b-49d9-8cf5-0e2aced56623', source='assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 12, 3, 13, 58, 1, 386305, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='Kantega is an IT consultancy, with offices in Trondheim, Oslo and Bergen', name='
# ...
